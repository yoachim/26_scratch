# %%
# compare the sorcha and moving object outputs
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
# %matplotlib inline

# %%
mo = np.load("baseline_v5.1.2_10yrs__granvik_5k_obs.npz")
mo_obs = mo["object_observations"].copy()
mo.close()

# %%
mo_obs
# Out:
# array([(   0,   83682, 'S.dat', 61155.96970328, 108.1037399 , 9.8736377 ,  1.00659495, -0.48673618, 78.11642539,  73.29066797, 0.98474154, 0.49202199, 26.05523891,   6.54314881, 1.11809905, -0.40942278, 0.21429924, 0.2725896 , 30., 21.42953456, 1.11944111, 61155.96970328,  175, 'y'),
#        (   0,   83706, 'S.dat', 61155.9798419 , 108.11410305, 9.86870091,  1.00743504, -0.48709234, 78.11722611,  73.29201852, 0.98475027, 0.49198936, 26.05514214,   6.55547463, 1.11901041, -0.40942278, 0.20935717, 0.26414543, 30., 21.58533743, 1.14296159, 61155.9798419 ,  175, 'y'),
#        (   0,   86799, 'S.dat', 61158.97004767, 111.2844216 , 8.37702326,  1.03689756, -0.51432265, 78.20266645,  73.83340116, 0.98794291, 0.48229915, 26.02196446,  10.18096284, 1.15744734, -0.40060616, 0.20815903, 0.2621093 , 30., 22.44630338, 1.18801783, 61158.97004767,  178, 'z'),
#        ...,
# ...

# %%
sorc_obs = pd.read_csv("gran_10y_h5.csv")

# %%
sorc_obs
# Out:
#          ObjID  fieldMJD_TAI  fieldRA_deg  fieldDec_deg      RA_deg  \
# 0         1368  60981.002345   263.940171    -25.278365  265.664128
# 1         1576  60981.002345   263.940171    -25.278365  264.967837
# 2          490  60981.002345   263.940171    -25.278365  263.377553
# 3         1846  60981.002345   263.940171    -25.278365  264.779887
# 4         3577  60981.002345   263.940171    -25.278365  263.804007
# ...        ...           ...          ...           ...         ...
# 1543879   3720  64632.271709    53.006584    -28.051969   54.209078
# 1543880   3354  64632.271709    53.006584    -28.051969   52.733815
# 1543881   3354  64632.272112    52.944954    -27.966947   52.733690
# 1543882   2317  64632.272112    52.944954    -27.966947   52.893454
# 1543883   1804  64632.273515    62.562981    -48.122405   63.719206
#
#            Dec_deg  astrometricSigma_deg optFilter  trailedSourceMag  \
# 0       -25.423647              0.000003         r          8.062771
# ...

# %%
id_test = 0

g1 = np.where(mo_obs["obj_id"] == id_test)[0]

g2 = np.where(sorc_obs["ObjID"].values == id_test)[0]

# %%
mo_obs["observationStartMJD"][g1].shape
# Out:
# (213,)

# %%
sorc_obs["fieldMJD_TAI"].values[g2].shape
# Out:
# (225,)

# %%
mo_obs.shape
# Out:
# (1504084,)

# %%
(sorc_obs.shape[0] - mo_obs.shape[0])/mo_obs.shape[0]
# Out:
# 0.026461288066357995
