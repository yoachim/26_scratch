# %%
import healpy as hp
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from rubin_scheduler.utils import ra_dec_nearest_interp, ra_dec2_hpid

# %%
nside = 8
hp_array = np.arange(hp.nside2npix(nside))
hp.mollview(hp_array)

# %%
ra = np.arange(0, 360, 30)
dec = np.arange(-90,90, 15)

# %%
hpid = ra_dec2_hpid(nside, ra, dec)
assign_val = hp_array[hpid]

interp_val = ra_dec_nearest_interp(ra, dec, hp_array)

# %%
assign_val
# Out:
# array([764, 756, 711, 632, 570, 477, 384, 291, 197, 136,  56,  11])

# %%
interp_val
# Out:
# array([765.5, 756. , 711. , 662.5, 570. , 477. , 383.5, 291. , 197. ,
#        104.5,  56. ,  11. ])

# %%
hpid, weights = hp.get_interp_weights(nside, ra[0], dec[0], lonlat=True)

# %%
weights
# Out:
# array([0.25, 0.25, 0.25, 0.25])

# %%
ra_dec2_hpid(nside, ra[0], dec[0])
# Out:
# np.int64(764)

# %%
hp_array.size
# Out:
# 768
