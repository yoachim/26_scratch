# %%
import healpy as hp
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
import healpy as hp
import numpy as np
import matplotlib.pylab as plt


arr = np.arange(hp.nside2npix(64))
hp.azeqview(arr, half_sky=True, lamb=True, rot=(180, 90, 0), xsize=800*2, ysize=800*2, reso=13/2,
            title="")
hp.graticule(dpar=45., dmer=45.)

#ax = plt.gca()
#circle = plt.Circle((0.5, 0.5), radius=0.468, transform=ax.transAxes, 
#                fill=False, edgecolor='black', linewidth=1)
#ax.add_patch(circle)
